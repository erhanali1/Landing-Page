# %% [markdown]
# # Capstone Project: Consumer Insights Data Analytics Externship of Beats by Dre

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Kindly use this template to get an overview of the structure that you need to follow in your capstone project.
#
# Ensure that the final insights that you produce in your analysis stand out and are easily accessible.
#
# You need to provide the code snippets that you used to run the code.

# %% [markdown]
# ## 1. Title Page
# **Project Title:** Consumer Insights Data Analytics Externship of Beats by Dre
# **Student Name:** Erhan Ali
# **Date:** 7/27/2024

# %% [markdown]
# ## 2. Table of Contents
# 1. Introduction
# 2. Data Description
# 3. Exploratory Data Analysis (EDA)
# 4. Sentiment Analysis
# 5. AI-Generated Insights
# 6. Comparative Analysis
# 7. Strategic Recommendations
# 8. Conclusion
# 9. References

# %% [markdown]
# ## 3. Introduction
#
# ### 3.1 Project Overview
# Briefly describe the purpose of the project and outline the key objectives.

# %%
# Introduction
This project aims to leverage consumer reviews to extract meaningful insights
for Beats by Dre. Through sentiment analysis and AI-driven insights, the project seeks to enhance understanding of
customer perceptions and identify areas for improvement.

# %% [markdown]
# ### 3.2 Background
# Provide context about Beats by Dre and the importance of consumer sentiment analysis in the tech industry.

# %%
# Background
Beats by Dre, known for its high-quality audio products, faces fierce competition in the market.
Understanding consumer sentiment is vital for the brand to adapt and thrive.
This analysis focuses on leveraging consumer feedback to uncover strengths and areas for improvement.

# %% [markdown]
# ## 4. Data Description
#
# ### 4.1 Data Sources
# Describe the sources of your data (e.g., Amazon reviews).

# %%
The primary source of data for this analysis is Amazon reviews.
The dataset includes reviews from Amazon customers for various products,
including Beats by Dre and its competitor brands such as Sony, Bose, Sennheiser,
and Jabra. These reviews provide valuable insights into customer sentiments, experiences,
and perceptions of the products. The dataset comprises text reviews, ratings, and other
metadata, which have been used for sentiment analysis and comparison across different brands.
The reviews were gathered using web scraping tools, specifically targeting products with a
substantial number of reviews to ensure a comprehensive analysis.

# %% [markdown]
# ### 4.2 Data Collection
# Explain the data gathering process, including any challenges faced and how they were overcome.

# %%
The data was gathered using web scraping tools, particularly the OxyLabs API, focusing on reviews with a
substantial number of comments to ensure a robust analysis.
The challenges included handling missing data and ensuring data consistency.

# %% [markdown]
# ### 4.3 Data Cleaning
# Outline the steps taken to clean and preprocess the data, highlighting any significant decisions made during this process.
#
# Load the data below and process cleaning here.

# %%
import pandas as pd

df = pd.read_csv('/content/cleaned_reviews.csv')

df.dropna(inplace=True)

df = pd.get_dummies(df, drop_first=True)

df.drop_duplicates(inplace=True)

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-a217fa4015fa> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('/content/cleaned_reviews.csv')
#       4
#       5 df.dropna(inplace=True)
#
# ...

# %% [markdown]
# ## 5. Exploratory Data Analysis (EDA)
#
# ### 5.1 Data Overview
# Provide a summary of the dataset, including key statistics (mean, median, mode, standard deviation, etc.).

# %%
df.describe()
# Out:
#         review_id  product_id       title      author      rating     content  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean   121.000000    2.152263  118.419753  112.078189    4.526749  121.000000
# std     70.292247    1.274943   68.245461   69.108117    0.675963   70.292247
# min      0.000000    0.000000    0.000000    0.000000    3.000000    0.000000
# 25%     60.500000    1.000000   59.500000   51.500000    4.000000   60.500000
# 50%    121.000000    3.000000  119.000000  112.000000    5.000000  121.000000
# 75%    181.500000    3.000000  176.500000  171.500000    5.000000  181.500000
# max    242.000000    4.000000  236.000000  232.000000    5.000000  242.000000
#
#         timestamp  profile_id  helpful_count  product_attributes
# count  243.000000  243.000000     243.000000          243.000000
# mean    89.806584  121.000000       1.666667            5.987654
# std     46.440040   70.292247       2.927499            4.836570
# ...

# %% [markdown]
# ### 5.2 Visualizations
# Include relevant visualizations (histograms, box plots, scatter plots, etc.) and explain what each visualization reveals about the data.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram
sns.histplot(df['rating'], bins=5, kde=False)
plt.title('Distribution of Ratings')
plt.show()

# Boxplot
sns.boxplot(x='rating', data=df)
plt.title('Box Plot of Ratings')
plt.show()

# %% [markdown]
# ### 5.3 Descriptive Statistics
# Discuss key findings from the descriptive statistics, highlighting any patterns, trends, or anomalies.

# %%
The average ratings for Beats by Dre products are generally high,
indicating positive customer satisfaction, though some negative ratings
suggest areas of concern. The ratings distribution shows a concentration
around higher values, but with some variance, indicating mixed experiences.
The presence of outliers, especially in lower ratings, highlights significant
dissatisfaction among certain users. Trends show that issues like battery life and
customer service are common points of critique, aligning with findings from sentiment analysis.
Overall, while the feedback is mostly positive, these areas offer opportunities for improvement.

# %% [markdown]
# ## 6. Sentiment Analysis
#
# ### 6.1 Methodology
# Explain the sentiment analysis techniques used (e.g., TextBlob, NLTK) and provide code snippets.

# %%
from textblob import TextBlob

def analyze_sentiment(text):
    text = str(text)
    blob = TextBlob(text)
    if blob.sentiment.polarity > 0:
        return 'Positive'
    elif blob.sentiment.polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

df['sentiment'] = df['content'].apply(analyze_sentiment)

# %% [markdown]
# ### 6.2 Results
# Present the sentiment analysis results, including visualizations of sentiment distribution, and discuss the overall sentiment towards Beats by Dre products.

# %%
sentiment_counts = df['sentiment'].value_counts()
sentiment_counts.plot(kind='bar', title='Sentiment Distribution')
plt.show()

# %% [markdown]
# ## 7. AI-Generated Insights
#
# ### 7.1 Using Gemini AI
# Briefly explain how Gemini AI was used to extract insights and include any relevant code snippets or explanations.

# %%
Gemini AI was employed to analyze the text of customer reviews to extract
insights into customer sentiments and experiences with Beats by Dre products.
The AI was used to classify reviews into positive, negative, and neutral categories
and to highlight specific aspects of the products that were frequently mentioned
in the reviews, such as sound quality, battery life, and build quality.

# %% [markdown]
# ### 7.2 Key Insights
# Summarize the key insights generated by Gemini AI, including specific examples of prompts used and the responses received.

# %%
Gemini AI analyzed customer reviews for Beats by Dre products,
revealing both positive and negative aspects. Customers frequently
praised the products for their excellent sound quality, comfortable
design, and stylish appearance, along with reliable performance and good
value for money. However, common complaints included dissatisfaction with
battery life, especially during prolonged use or when using active features,
and some users felt the products were overpriced compared to competitors.
Specific feedback highlighted issues with battery life, such as needing frequent
recharges, which could be a focus for improvement. Overall, the insights emphasize
the strengths in sound quality and design while suggesting areas for enhancement,
particularly in battery performance and value perception.

# %% [markdown]
# ### 7.3 Interpretation
# Discuss how these insights can be interpreted and their relevance to Beats by Dre.

# %%
Positive feedback on sound quality and design confirms these as brand strengths,
while recurring complaints about battery life and price suggest areas for improvement.
Addressing battery life issues and reconsidering pricing or value communication could
enhance customer satisfaction and competitiveness. These insights can inform product
development and marketing strategies to better meet customer expectations and strengthen market positioning.

# %% [markdown]
# ## 8. Comparative Analysis
#
# ### 8.1 Competitor Overview
# List the competitors analyzed and provide a brief overview of their market positioning.

# %%
Competitors analyzed include Sony, Bose, Sennheiser, and Jabra.
Sony is known for high-quality noise-canceling headphones;
Bose is a leader in premium audio products; Sennheiser focuses on
professional-grade sound quality; Jabra offers versatile, feature-rich headphones.
All competitors are positioned in the mid-to-high-end market, emphasizing sound quality
and advanced features.

# %% [markdown]
# ### 8.2 Comparison of Sentiments
# Compare the sentiment analysis results of Beats by Dre with its competitors using visualizations to highlight differences and similarities.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/cleaned_reviews.csv')

# Grouping the data by product_id and calculating the mean rating
average_ratings = df.groupby('product_id')['rating'].mean().reset_index()

# Plotting the average ratings by product_id
plt.figure(figsize=(10, 6))
sns.barplot(x='product_id', y='rating', data=average_ratings)
plt.title('Average Ratings by Product ID')
plt.xlabel('Product ID')
plt.ylabel('Average Rating')
plt.show()

# Plotting the distribution of ratings by product_id
plt.figure(figsize=(12, 8))
sns.boxplot(x='product_id', y='rating', data=df)
plt.title('Rating Distribution by Product ID')
plt.xlabel('Product ID')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# ### 8.3 SWOT Analysis
# Conduct a SWOT analysis (Strengths, Weaknesses, Opportunities, Threats) for Beats by Dre based on the comparative data.

# %%
Strengths: Strong brand recognition, high-quality sound
Weaknesses: Battery life issues, high price
Opportunities: Expansion into new markets, technological advancements
Threats: Intense competition, price sensitivity

# %% [markdown]
# ## 9. Strategic Recommendations
#
# ### 9.1 Product Improvements
# Based on the analysis, suggest specific product improvements.

# %%
To address consumer concerns, it is recommended that Beats by Dre focus on
enhancing battery life and integrating new features such as Always-On Display and better water resistance.

# %% [markdown]
# ### 9.2 Marketing Strategies
# Provide recommendations for marketing strategies that could enhance consumer perception and satisfaction.

# %%
To enhance consumer perception and satisfaction, Beats by Dre could focus on
highlighting unique product features like sound quality and design in their
marketing campaigns. Collaborations with popular artists and influencers can
help reach a wider audience. Offering promotions and bundling deals can attract
price-sensitive customers. Additionally, expanding customer support and providing
personalized user experiences can improve overall satisfaction and brand loyalty.

# %% [markdown]
# ### 9.3 Future Research
# Suggest areas for future research or additional data that could be collected to further enhance the analysis.

# %%
Future studies could focus on exploring consumer preferences for emerging features
and technologies in audio products and continuously monitoring competitor strategies and market trends.

# %% [markdown]
# ## 10. Conclusion
# Summarize the key findings and their implications, and reflect on the overall project and its contribution to understanding consumer sentiment for Beats by Dre.

# %%
The key findings revealed that customers highly value the superior sound quality,
stylish design, and brand prestige of Beats products. However, there were notable
complaints about high prices, durability issues, and concerns about battery life. Our
comparative analysis showed that competitors like Sony and Bose often receive better feedback,
particularly regarding value for money and durability, suggesting areas for potential improvement
for Beats. Based on these insights, we recommend that Beats focus on offering more competitive pricing,
enhancing product durability, and emphasizing the brand's unique strengths in their marketing strategies.
These actions can help Beats by Dre better align with consumer expectations and improve its
market positioning.

# %% [markdown]
# ## 11. References
# List all the sources, tools, and references used in the project.

# %%
Amazon Product Reviews Dataset - The dataset used for the analysis was collected from Amazon reviews. https://www.amazon.com/
Pandas Documentation - For data manipulation and analysis. https://pandas.pydata.org/pandas-docs/stable/
Matplotlib Documentation - For data visualization.
TextBlob Documentation - For sentiment analysis. https://textblob.readthedocs.io/en/dev/
Google Gemini AI - For AI-generated insights. https://ai.google/
Seaborn Documentation - For advanced visualizations.
OxyLabs API - Used for scraping Amazon reviews. https://oxylabs.io/home
